# %%
import pandas as pd
csv = pd.read_csv('book_data.csv')
csv.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                            book_desc  \
# 0  Winning will make you famous. Losing means cer...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
#
#                          book_edition book_format    book_isbn book_pages  \
# 0                                 NaN   Hardcover  9.78044E+12  374 pages
# 1                          US Edition   Paperback  9.78044E+12  870 pages
# 2                    50th Anniversary   Paperback  9.78006E+12  324 pages
# ...

# %%
ar = csv['genres'].value_counts()
ar1 = []
for i in ar.index:
    if i == "":
        ar1.append("")
    else:
        a = i.split('|')
        ar1.append(a[0])
ar1[0:10]
# Out:
# ['Fiction',
#  'Novels',
#  'Poetry',
#  'Science Fiction',
#  'Romance',
#  'Nonfiction',
#  'Fantasy',
#  'Fantasy',
#  'Childrens',
#  'Fantasy']

# %%
len(csv.index)
# Out:
# 54301

# %%
ar1=pd.Series(ar1)

# %%
csv=pd.concat([csv,ar1], ignore_index=True, axis=1)
csv.head()
# Out:
#                                                   0   \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                                   1   \
# 0  Winning will make you famous. Losing means cer...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
#
#                                    2          3            4          5   \
# 0                                 NaN  Hardcover  9.78044E+12  374 pages
# 1                          US Edition  Paperback  9.78044E+12  870 pages
# 2                    50th Anniversary  Paperback  9.78006E+12  324 pages
# ...

# %%
csv1 = csv.drop([10,7,8,2,11],axis=1,inplace=True)

# %%
csv.head()
# Out:
#                                                   0   \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                                   1          3            4   \
# 0  Winning will make you famous. Losing means cer...  Hardcover  9.78044E+12
# 1  There is a door at the end of a silent corrido...  Paperback  9.78044E+12
# 2  The unforgettable novel of a childhood in a sl...  Paperback  9.78006E+12
# 3  «È cosa ormai risaputa che a uno scapolo in po...  Paperback  9.78068E+12
# 4  About three things I was absolutely positive.F...  Paperback  9.78032E+12
#
#           5     6                                          9                12
# 0  374 pages  4.33                           The Hunger Games          Fiction
# ...

# %%
csv[12].value_counts()
# Out:
# Fiction                         4030
# Fantasy                         3912
# Romance                         2307
# Nonfiction                      1973
# Young Adult                     1925
# Historical                      1494
# Sequential Art                  1041
# Mystery                         1032
# Classics                         857
# Science Fiction                  843
# History                          742
# Horror                           636
# Childrens                        534
# Poetry                           517
# Philosophy                       429
# Cultural                         389
# Religion                         372
# Biography                        327
# Short Stories                    323
# Paranormal                       320
# Thriller                         318
# Christian Fiction                316
# Christian                        281
# Science                          273
# European Literature              270
# ...

# %%
csv.shape
# Out:
# (54301, 8)

# %%
csv.loc[(csv[6]>= 3.5)]
# Out:
#                                                       0   \
# 0                                        Suzanne Collins
# 1                             J.K. Rowling|Mary GrandPré
# 2                                             Harper Lee
# 3      Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                        Stephenie Meyer
# 5                                           Markus Zusak
# 6                              C.S. Lewis|Pauline Baynes
# 7                                          George Orwell
# 8                                      Margaret Mitchell
# 9                                         J.R.R. Tolkien
# 10                                            John Green
# 11                                         Douglas Adams
# 12                                      Shel Silverstein
# 13     Emily Brontë|Richard J. Dunn|David Timson|Char...
# 14                                             Dan Brown
# ...

# %%
csv.loc
