# %%
import pandas as pd
CE=pd.read_csv("DatafinitiElectronicsProductsPricingData.csv")
CE
# Out:
#                          id  prices.amountMax  prices.amountMin  \
# 0      AVphzgbJLJeJML43fA0o            104.99            104.99
# 1      AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2      AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3      AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4      AVpgMuGwLJeJML43KY_c             66.99             66.99
# 5      AVpgMuGwLJeJML43KY_c             66.00             66.00
# 6      AVpgMuGwLJeJML43KY_c             74.99             74.99
# 7      AVpgMuGwLJeJML43KY_c             65.99             65.99
# 8      AVpgMuGwLJeJML43KY_c             69.99             69.99
# 9      AVpgMuGwLJeJML43KY_c             69.00             64.00
# 10     AVpgMuGwLJeJML43KY_c             69.99             69.99
# 11     AVpgMuGwLJeJML43KY_c             64.99             64.99
# 12     AVpgMuGwLJeJML43KY_c             64.99             64.99
# 13     AVpe9FXeLJeJML43zHrq             23.99             23.99
# ...

# %%
CE.groupby(["prices.isSale"])["prices.amountMax"].sum()
# Out:
# prices.isSale
# False    5.135377e+06
# True     2.300398e+06
# Name: prices.amountMax, dtype: float64

# %%
limpo = CE.drop(['Unnamed: 26',"Unnamed: 27","Unnamed: 28","Unnamed: 29","Unnamed: 30",'sourceURLs','manufacturerNumber','keys','imageURLs','dateAdded','dateUpdated','prices.sourceURLs','asins'],axis=1)

# %%
limpo.head()
# Out:
#                      id  prices.amountMax  prices.amountMin  \
# 0  AVphzgbJLJeJML43fA0o            104.99            104.99
# 1  AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2  AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3  AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4  AVpgMuGwLJeJML43KY_c             66.99             66.99
#
#   prices.availability prices.condition prices.currency  \
# 0                 Yes              New             USD
# 1            In Stock              New             USD
# 2            In Stock              New             USD
# 3                 Yes              New             USD
# 4                 Yes              New             USD
#
#                                      prices.dateSeen  prices.isSale  \
# 0  2017-03-30T06:00:00Z,2017-03-10T22:00:00Z,2017...          False
# 1                               2017-12-14T06:00:00Z           True
# ...

# %%
condicao = CE['prices.condition']
condicao.head()
# Out:
# 0    New
# 1    New
# 2    New
# 3    New
# 4    New
# Name: prices.condition, dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
Sale = encoder.fit_transform(condicao)
Sale.toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-d91874b8de3d> in <module>
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 encoder = OneHotEncoder()
# ----> 3 Sale = encoder.fit_transform(condicao)
#       4 Sale.toarray()
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     514                 self._categorical_features, copy=True)
#     515         else:
# --> 516             return self.fit(X).transform(X)
#     517
#     518     def _legacy_transform(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     425             return self
#     426         else:
# --> 427             self._fit(X, handle_unknown=self.handle_unknown)
#     428             return self
#     429
#
# ...
